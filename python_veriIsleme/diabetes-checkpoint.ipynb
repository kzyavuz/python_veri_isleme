# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
datas = pd.read_csv("diabetes.csv")

# %% [markdown]
# 1-yaşa göre diyabet olma oranı
# 2-hamileliğe göre diyabet olma oranı
# 3-glukoz oranına göre diyabet olma olasılığı
# 4-vücut kitle indeksi göre diyabet olma olasılığı
# 5-vücuttaki insülin oranına göre diyabet olma olasılığı
# 7-aile ağacına göre  diyabet olma olasılığı # bu yapılmadı
# 8-glikoz ve insülin oranına göre diyabet olma olasılığı
# - 18 Sorgu - 6 Görsel |
# 9-deri kalınlığına göre diyabet olma olasılığı
# 10-kan basıncı ve glukoz oranına göre diyabet olma olasılığı
# 11-veri tabanındaki toplam veriye göre diyabet olma olasılığı # yapılmadı
# 12-yaş ve glukoz oranına göre diyabet olma olasılığı
# 13-vücut kitle endeksi ve kan basıncına göre diyabet olma olasılığı # yapılmadı
# 14-yaşa göre vücut kitle endeksi
# 15-hamilelik sayısına göre deri kalınlığı oranı
# - 16 Sorgu - 4 Görsel

# %%
df = pd.DataFrame(datas)

df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df1 = df[(df["Age"] > 30) & (df["Outcome"] == 1)] # 30 yaş üstü diyabet olanlar
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df2 = df[(df["Age"] > 30) & (df["Outcome"] == 0)] # 30 yaş üstü diyabet olmayanlar
df2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 12            10      139             80              0        0  27.1
# 18             1      103             30             38       83  43.3
# 21             8       99             84              0        0  35.4
# 28            13      145             82             19      110  22.2
# ..           ...      ...            ...            ...      ...   ...
# 745           12      100             84             33      105  30.0
# 747            1       81             74             41       57  46.3
# 756            7      137             90             41        0  32.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
df3 = df[(df["Age"] < 30) & (df["Outcome"] == 1)] # 30 yaş altı diyabet olanlar
df3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 6              3       78             50             32       88  31.0
# 23             9      119             80             35        0  29.0
# 31             3      158             76             36      245  31.6
# 38             2       90             68             42        0  38.2
# 45             0      180             66             39        0  42.0
# ..           ...      ...            ...            ...      ...   ...
# 731            8      120             86              0        0  28.4
# 732            2      174             88             37      120  44.5
# 746            1      147             94             41        0  49.3
# 750            4      136             70              0        0  31.2
# 753            0      181             88             44      510  43.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 6                       0.248   26        1
# ...

# %%
df4 = df[(df["Age"] < 30) & (df["Outcome"] == 0)] # 30 yaş altı diyabet olmayanlar
df4
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3              1       89             66             23       94  28.1
# 7             10      115              0              0        0  35.3
# 20             3      126             88             41      235  39.3
# 27             1       97             66             15      140  23.2
# 32             3       88             58             11       54  24.8
# ..           ...      ...            ...            ...      ...   ...
# 752            3      108             62             24        0  26.0
# 758            1      106             76              0        0  37.5
# 760            2       88             58             26       16  28.4
# 764            2      122             70             27        0  36.8
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 3                       0.167   21        0
# ...

# %%
x = np.array(["Sarı","Yeşil","Siyah", "Mavi", "Kırmızı"])
y = np.array([len(df1),len(df2),len(df3),len(df4),len(df)])

plt.bar(x[0],y[0], color="yellow", label="30 yaş üstü diyabet olanlar")
plt.bar(x[1],y[1], color="green", label="30 yaş üstü diyabet olmayanlar")
plt.bar(x[2],y[2], color="black", label="30 yaş altı diyabet olanlar")
plt.bar(x[3],y[3], color="blue", label="30 yaş altı diyabet olmayanlar")
plt.bar(x[4],y[4], color="red", label="Toplam")

plt.legend()
plt.show()

# %%
x = np.array(["Sarı","Yeşil","Kırmızı"])
y = np.array([len(df1),len(df2), len(df) - len(df3) - len(df4)])

plt.bar(x[0],y[0], color="yellow", label="30 yaş üstü diyabet olanlar")
plt.bar(x[1],y[1], color="green", label="30 yaş üstü diyabet olmayanlar")
plt.bar(x[2],y[2], color="red", label="30 Yaş üstü toplamı")

plt.legend()
plt.show()

# %%
df1 = df[(df["Pregnancies"] > 0) & (df["Outcome"] == 1)] # En az 1 kere hamile kalmış diyabet olanlar
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# ..           ...      ...            ...            ...      ...   ...
# 754            8      154             78             32        0  32.4
# 755            1      128             88             39      110  36.5
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df2 = df[(df["Pregnancies"] > 0) & (df["Outcome"] == 0)] # En az 1 kere doğum yapmış diyabet olmayanlar
df2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
x = np.array(["Sarı","Yeşil","Kırmızı", "black"])
y = np.array([len(df1),len(df2), len(df1) + len(df2),len(df) - len(df1) - len(df2)])

plt.bar(x[0],y[0], color="yellow", label="En az 1 kere hamile kalmış diyabet olanlar")
plt.bar(x[1],y[1], color="green", label="En az 1 kere hamile kalmış diyabet olmayanlar")
plt.bar(x[2],y[2], color="red", label="En az 1 kere hamile kalanlar")
plt.bar(x[3],y[3], color="black", label="En az 1 kere bile hamile kalmayanlar")

plt.legend()
plt.show()

# %%
df1 = df[(df["Glucose"] > df["Glucose"].mean()) & (df["Outcome"] == 1)] # Ortalamanın üstünde glikoz oranı olan ve diyabet olanlar
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df2 = df[(df["Glucose"] > df["Glucose"].mean()) & (df["Outcome"] == 0)] # Ortalamanın üstünde glikoz oranı olan ve diyabet olmayanlar
df2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 12            10      139             80              0        0  27.1
# 20             3      126             88             41      235  39.3
# 28            13      145             82             19      110  22.2
# 34            10      122             78             31        0  27.6
# 36            11      138             76              0        0  33.2
# ..           ...      ...            ...            ...      ...   ...
# 744           13      153             88             37      140  40.6
# 751            1      121             78             39       74  39.0
# 756            7      137             90             41        0  32.0
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 12                      1.441   57        0
# ...

# %%
df3 = df[(df["Glucose"] < df["Glucose"].mean()) & (df["Outcome"] == 1)] # Ortalamanın altında glikoz oranı olan ve diyabet olanlar
df3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 6              3       78             50             32       88  31.0
# 15             7      100              0              0        0  30.0
# 16             0      118             84             47      230  45.8
# 17             7      107             74              0        0  29.6
# 19             1      115             70             30       96  34.6
# ..           ...      ...            ...            ...      ...   ...
# 709            2       93             64             32      160  38.0
# 719            5       97             76             27        0  35.6
# 731            8      120             86              0        0  28.4
# 739            1      102             74              0        0  39.5
# 740           11      120             80             37      150  42.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 6                       0.248   26        1
# ...

# %%
df4 = df[(df["Glucose"] < df["Glucose"].mean()) & (df["Outcome"] == 0)] # Ortalamanın altında glikoz oranı olan ve diyabet olmayanlar
df4
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 758            1      106             76              0        0  37.5
# 760            2       88             58             26       16  28.4
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
y = np.array([len(df1),len(df2),len(df3),len(df4)])
mylabels = [
    "Ortalamanın üstünde glikoz oranı olan ve diyabet olanlar",
    "Ortalamanın üstünde glikoz oranı olan ve diyabet olmayanlar",
    "Ortalamanın altında glikoz oranı olan ve diyabet olanlar",
    "Ortalamanın altında glikoz oranı olan ve diyabet olmayanlar",
           ];
plt.pie(y, labels=mylabels, explode = [0.1,0.1,0.1,0.1], autopct='%1.1f%%')

plt.show()

# %%
df1 = df[(df["BMI"] > df["BMI"].mean()) & (df["Outcome"] == 1)] # Vücut kitle indeksi ortalamanın üstünde olan diyabetliler
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 4              0      137             40             35      168  43.1
# 11            10      168             74              0        0  38.0
# 16             0      118             84             47      230  45.8
# 19             1      115             70             30       96  34.6
# ..           ...      ...            ...            ...      ...   ...
# 754            8      154             78             32        0  32.4
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df2 = df[(df["BMI"] > df["BMI"].mean()) & (df["Outcome"] == 0)] # Vücut kitle indeksi ortalamanın üstünde olan diyabetli olmayanlar
df2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# 18             1      103             30             38       83  43.3
# 20             3      126             88             41      235  39.3
# 21             8       99             84              0        0  35.4
# ..           ...      ...            ...            ...      ...   ...
# 751            1      121             78             39       74  39.0
# 756            7      137             90             41        0  32.0
# 758            1      106             76              0        0  37.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
#
#      DiabetesPedigreeFunction  Age  Outcome
# 7                       0.134   29        0
# ...

# %%
df3 = df[(df["BMI"] < df["BMI"].mean()) & (df["Outcome"] == 1)] # Vücut kitle indeksi ortalamanın altında olan diyabetliler
df3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2              8      183             64              0        0  23.3
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 13             1      189             60             23      846  30.1
# ..           ...      ...            ...            ...      ...   ...
# 730            3      130             78             23       79  28.4
# 731            8      120             86              0        0  28.4
# 749            6      162             62              0        0  24.3
# 750            4      136             70              0        0  31.2
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 2                       0.672   32        1
# ...

# %%
df4 = df[(df["BMI"] < df["BMI"].mean()) & (df["Outcome"] == 0)] # Vücut kitle indeksi ortalamanın altında olan diyabet olmayanlar
df4
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 12            10      139             80              0        0  27.1
# 27             1       97             66             15      140  23.2
# ..           ...      ...            ...            ...      ...   ...
# 752            3      108             62             24        0  26.0
# 760            2       88             58             26       16  28.4
# 762            9       89             62              0        0  22.5
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
y = np.array([len(df1),len(df2),len(df3),len(df4)])
mylabels = [
    "Vücut kitle indeksi ortalamanın üstünde olan diyabetli olanlar",
    "Vücut kitle indeksi ortalamanın üstünde olan diyabetli olmayanlar",
    "Vücut kitle indeksi ortalamanın altında olan diyabetli olanlar",
    "Vücut kitle indeksi ortalamanın altında olan diyabetli olmayanlar",
           ];
plt.pie(y, labels=mylabels, explode = [0.2,0.2,0,0], autopct='%1.1f%%')

plt.show()

# %%
df1 = df[(df["Insulin"] >= 120) & (df["Outcome"] == 1)] # Yüksek derece ve üstünde insülin oranı olan ve diyabet olanlar
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 4              0      137             40             35      168  43.1
# 8              2      197             70             45      543  30.5
# 13             1      189             60             23      846  30.1
# 14             5      166             72             19      175  25.8
# 16             0      118             84             47      230  45.8
# ..           ...      ...            ...            ...      ...   ...
# 722            1      149             68             29      127  29.3
# 732            2      174             88             37      120  44.5
# 740           11      120             80             37      150  42.3
# 748            3      187             70             22      200  36.4
# 753            0      181             88             44      510  43.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 4                       2.288   33        1
# ...

# %%
df2 = df[(df["Insulin"] >= 120) & (df["Outcome"] == 0)] # Yüksek derece ve üstünde insülin oranı olan ve diyabet olmayanlar
df2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 20             3      126             88             41      235  39.3
# 27             1       97             66             15      140  23.2
# 35             4      103             60             33      192  24.0
# 54             7      150             66             42      342  34.7
# 59             0      105             64             41      142  41.5
# ..           ...      ...            ...            ...      ...   ...
# 733            2      106             56             27      165  29.0
# 736            0      126             86             27      120  27.4
# 738            2       99             60             17      160  36.6
# 744           13      153             88             37      140  40.6
# 763           10      101             76             48      180  32.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 20                      0.704   27        0
# ...

# %%
df3 = df[(df["Insulin"] < 120) & (df["Outcome"] == 1)] # Yüksek derecenin altında insülin oranı olan ve diyabet olanlar
df3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 6              3       78             50             32       88  31.0
# 9              8      125             96              0        0   0.0
# 11            10      168             74              0        0  38.0
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df4 = df[(df["Insulin"] < 120) & (df["Outcome"] == 0)] # Yüksek derecenin altında insülin oranı olan ve diyabet olmayanlar
df4
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 760            2       88             58             26       16  28.4
# 762            9       89             62              0        0  22.5
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
y = np.array([len(df1),len(df2),len(df3),len(df4)])
mylabels = [
    "Yüksek derece ve üstünde insülin oranı olan ve diyabet olanlar",
    "Yüksek derece ve üstünde insülin oranı olan ve diyabet olmayanlar",
    "Yüksek derecenin altında insülin oranı olan ve diyabet olanlar",
    "Yüksek derecenin altında insülin oranı olan ve diyabet olmayanlar",
           ];
plt.pie(y, labels=mylabels, explode = [0.2,0.2,0,0], autopct='%1.1f%%')

plt.show()

# %% [markdown]
# # Selim

# %%
df1 = df[(df["SkinThickness"] > df["SkinThickness"].mean()) & (df["Outcome"] == 1)] # Cilt kalınlığı ortalamanın üstünde olup diyabet olanlar
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# 13             1      189             60             23      846  30.1
# ..           ...      ...            ...            ...      ...   ...
# 748            3      187             70             22      200  36.4
# 753            0      181             88             44      510  43.3
# 754            8      154             78             32        0  32.4
# 755            1      128             88             39      110  36.5
# 761            9      170             74             31        0  44.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df2 = df[(df["SkinThickness"] > df["SkinThickness"].mean()) & (df["Outcome"] == 0)] # Cilt kalınlığı ortalamanın üstünde olup diyabet olmayanlar
df2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 18             1      103             30             38       83  43.3
# 20             3      126             88             41      235  39.3
# 30             5      109             75             26        0  36.0
# ..           ...      ...            ...            ...      ...   ...
# 760            2       88             58             26       16  28.4
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
df3 = df[(df["SkinThickness"] < df["SkinThickness"].mean()) & (df["Outcome"] == 1)] # Cilt kalınlığı ortalamanın altında olup diyabet olanlar
df3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2              8      183             64              0        0  23.3
# 9              8      125             96              0        0   0.0
# 11            10      168             74              0        0  38.0
# 14             5      166             72             19      175  25.8
# 15             7      100              0              0        0  30.0
# ..           ...      ...            ...            ...      ...   ...
# 749            6      162             62              0        0  24.3
# 750            4      136             70              0        0  31.2
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 2                       0.672   32        1
# ...

# %%
y = np.array([len(df1),len(df2),len(df3),len(df4)])
mylabels = [
    "Cilt kalınlığı ortalamanın üstünde olup diyabet olanlar",
    "Cilt kalınlığı ortalamanın üstünde olup diyabet olmayanlar",
    "Cilt kalınlığı ortalamanın altında olup diyabet olanlar",
    "Cilt kalınlığı ortalamanın altında olup diyabet olmayanlar",
           ];
plt.pie(y, labels=mylabels, explode = [0.2,0.2,0,0], autopct='%1.1f%%')

plt.show()

# %%
# 90 üzeri hipertansiyon
df1 = df[(df["BloodPressure"] > 90) & (df["Outcome"] == 1)] # Kan basıncı 90'ın üzerinde olup diyabet olanlar
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 9              8      125             96              0        0   0.0
# 24            11      143             94             33      146  36.6
# 43             9      171            110             24      240  45.4
# 84             5      137            108              0        0  48.8
# 115            4      146             92              0        0  31.2
# 177            0      129            110             46      130  67.1
# 187            1      128             98             41       58  32.0
# 207            5      162            104              0        0  37.7
# 303            5      115             98              0        0  52.9
# 369            1      133            102             28      140  32.8
# 387            8      105            100             36        0  43.3
# 440            0      189            104             25        0  34.3
# ...

# %%
df2 = df[(df["BloodPressure"] > 90) & (df["Outcome"] == 0)] # Kan basıncı 90'ın üzerinde olup diyabet olmayanlar
df2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 10             4      110             92              0        0  37.6
# 29             5      117             92              0        0  34.1
# 33             6       92             92              0        0  19.9
# 42             7      106             92             18        0  22.7
# 67             2      109             92              0        0  42.7
# 102            0      125             96              0        0  22.5
# 106            1       96            122              0        0  22.4
# 212            7      179             95             31        0  34.2
# 362            5      103            108             37        0  39.2
# 379            0       93            100             39       72  43.4
# 428            0      135             94             46      145  40.6
# 464           10      115             98              0        0  24.0
# ...

# %%
df4 = df[(df["SkinThickness"] < df["SkinThickness"].mean()) & (df["Outcome"] == 0)] # Cilt kalınlığı ortalamanın altında olup diyabet olmayanlar
df4
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# 12            10      139             80              0        0  27.1
# 21             8       99             84              0        0  35.4
# ..           ...      ...            ...            ...      ...   ...
# 738            2       99             60             17      160  36.6
# 741            3      102             44             20       94  30.8
# 742            1      109             58             18      116  28.5
# 758            1      106             76              0        0  37.5
# 762            9       89             62              0        0  22.5
#
#      DiabetesPedigreeFunction  Age  Outcome
# 5                       0.201   30        0
# ...

# %%
df3 = df[(df["BloodPressure"] < 90) & (df["Outcome"] == 1)] # Kan basıncı 90'ın altında olup diyabet olanlar
df3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 754            8      154             78             32        0  32.4
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df4 = df[(df["BloodPressure"] < 90) & (df["Outcome"] == 0)] # Kan basıncı 90'ın altında olup diyabet olmayanlar
df4
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 12            10      139             80              0        0  27.1
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
y = np.array([len(df1),len(df2),len(df3),len(df4)])
mylabels = [
    "Kan basıncı 90'ın üzerinde olup diyabet olanlar",
    "Kan basıncı 90'ın üzerinde olup diyabet olmayanlar",
    "Kan basıncı 90'ın altında olup diyabet olanlar",
    "Kan basıncı 90'ın altında olup diyabet olmayanlar",
           ];
plt.pie(y, labels=mylabels, explode = [0.4,0.4,0.1,0.1], autopct='%1.1f%%')

plt.show()

# %%
df1 = df[(df["Age"] > df["Age"].mean()) & (df["Outcome"] == 1)] # Yaş ortalamasının üzerinde olup diyabet olanlar
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 11            10      168             74              0        0  38.0
# 13             1      189             60             23      846  30.1
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df2 = df[(df["Age"] > df["Age"].mean()) & (df["Outcome"] == 0)] # Yaş ortalamasının üzerinde olup diyabet olmayanlar
df2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 12            10      139             80              0        0  27.1
# 21             8       99             84              0        0  35.4
# 28            13      145             82             19      110  22.2
# 29             5      117             92              0        0  34.1
# 30             5      109             75             26        0  36.0
# ..           ...      ...            ...            ...      ...   ...
# 737            8       65             72             23        0  32.0
# 744           13      153             88             37      140  40.6
# 745           12      100             84             33      105  30.0
# 756            7      137             90             41        0  32.0
# 763           10      101             76             48      180  32.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 12                      1.441   57        0
# ...

# %%
df3 = df[(df["Age"] < df["Age"].mean()) & (df["Outcome"] == 1)] # Yaş ortalamasının altında olup diyabet olanlar
df3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 15             7      100              0              0        0  30.0
# 16             0      118             84             47      230  45.8
# ..           ...      ...            ...            ...      ...   ...
# 731            8      120             86              0        0  28.4
# 732            2      174             88             37      120  44.5
# 746            1      147             94             41        0  49.3
# 750            4      136             70              0        0  31.2
# 753            0      181             88             44      510  43.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 2                       0.672   32        1
# ...

# %%
df4 = df[(df["Age"] < df["Age"].mean()) & (df["Outcome"] == 0)] # Yaş ortalamasının altında olup diyabet olmayanlar
df4
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 760            2       88             58             26       16  28.4
# 762            9       89             62              0        0  22.5
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
y = np.array([len(df1),len(df2),len(df3),len(df4)])
mylabels = [
    "Yaş ortalamasının üzerinde olup diyabet olanlar",
    "Yaş ortalamasının üzerinde olup diyabet olmayanlar",
    "Yaş ortalamasının altında olup diyabet olanlar",
    "Yaş ortalamasının altında olup diyabet olmayanlar",
           ];
plt.pie(y, labels=mylabels, explode = [0.1,0.1,0.1,0], autopct='%1.1f%%')

plt.show()

# %%
# En az 1 kere hamile kalmış ve deri kalınlığı ortalamanın üzerinde olup diyabet olanlar
df1 = df[((df["Pregnancies"] > 0) & (df["SkinThickness"] > df["SkinThickness"].mean())) & (df["Outcome"] == 1)]
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# 13             1      189             60             23      846  30.1
# 19             1      115             70             30       96  34.6
# ..           ...      ...            ...            ...      ...   ...
# 746            1      147             94             41        0  49.3
# 748            3      187             70             22      200  36.4
# 754            8      154             78             32        0  32.4
# 755            1      128             88             39      110  36.5
# 761            9      170             74             31        0  44.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# En az 1 kere hamile kalmış ve deri kalınlığı ortalamanın üzerinde olup diyabet olmayanlar
df2 = df[((df["Pregnancies"] > 0) & (df["SkinThickness"] > df["SkinThickness"].mean())) & (df["Outcome"] == 0)]
df2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# En az 1 kere hamile kalmış ve deri kalınlığı ortalamanın altında olup diyabet olanlar
df1 = df[((df["Pregnancies"] > 0) & (df["SkinThickness"] < df["SkinThickness"].mean())) & (df["Outcome"] == 1)]
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2              8      183             64              0        0  23.3
# 9              8      125             96              0        0   0.0
# 11            10      168             74              0        0  38.0
# 14             5      166             72             19      175  25.8
# 15             7      100              0              0        0  30.0
# ..           ...      ...            ...            ...      ...   ...
# 743            9      140             94              0        0  32.7
# 749            6      162             62              0        0  24.3
# 750            4      136             70              0        0  31.2
# 759            6      190             92              0        0  35.5
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 2                       0.672   32        1
# ...

# %%
# En az 1 kere hamile kalmış ve deri kalınlığı ortalamanın altında olup diyabet olmayanlar
df2 = df[((df["Pregnancies"] > 0) & df["SkinThickness"] < df["SkinThickness"].mean()) & (df["Outcome"] == 0)]
df2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
y = np.array([len(df1),len(df2),len(df3),len(df4)])
mylabels = [
    "En az 1 kere hamile kalmış ve deri kalınlığı ortalamanın üzerinde olup diyabet olanlar",
    "En az 1 kere hamile kalmış ve deri kalınlığı ortalamanın üzerinde olup diyabet olmayanlar",
    "En az 1 kere hamile kalmış ve deri kalınlığı ortalamanın altında olup diyabet olanlar",
    "En az 1 kere hamile kalmış ve deri kalınlığı ortalamanın altında olup diyabet olmayanlar",
           ];
plt.pie(y, labels=mylabels, explode = [0.1,0.1,0.1,0.1], autopct='%1.1f%%', shadow=True)

plt.show()

# %%
df1 = df[df["Outcome"] == 1] # Diyabet hastası olanlar
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
x = np.array(["Sarı","Yeşil","Siyah"])
y = np.array([len(df1),len(df) - len(df1),len(df)])

adet = "Diyabet hastası olanlar " + str(len(df1)) + " adet"
adet1 = "Diyabet hastası olmayanlar " + str(len(df) - len(df1)) + " adet"
adet2 = "Toplam " + str(len(df)) + " adet"

plt.bar(x[0],y[0], color="yellow", label=adet)
plt.bar(x[1],y[1], color="green", label=adet1)
plt.bar(x[2],y[2], color="red", label=adet2)

plt.legend()
plt.show()
